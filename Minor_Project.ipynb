# %% [markdown]
# <a href="https://colab.research.google.com/github/ria-2511/Minor-Project----Image-Classifier/blob/master/Minor_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as np 
import numpy as np 
import cv2 
import os

# %%
# !pip install bing-image-downloader

# %%
# !ls
# Out:
# drive  sample_data

# %%
cd /content/drive/My Drive/Minor-Project
# Out:
# /content/drive/My Drive/Minor-Project

# %%
# !ls
# Out:
# images

# %%
# !mkdir images
# Out:
# mkdir: cannot create directory ‘images’: File exists

# %%
cd images
# Out:
# /content/drive/My Drive/Minor-Project/images

# %%
from bing_image_downloader import downloader
downloader.download("tomato vegetable", limit = 5 , output_dir = 'images' )
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 5 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://joshtom.files.wordpress.com/2010/07/tomato.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://cdn.britannica.com/16/187216-131-FB186228.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://media.mnn.com/assets/images/2015/04/tomato.jpg.653x0_q80_crop-smart.jpg
# [!] Issue getting: https://media.mnn.com/assets/images/2015/04/tomato.jpg.653x0_q80_crop-smart.jpg
# [!] Error:: <urlopen error [Errno -2] Name or service not known>
# [%] Downloading Image #3 from https://upload.wikimedia.org/wikipedia/commons/8/88/Bright_red_tomato_and_cross_section02.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.sciencealert.com/images/2018-05/processed/GettyImages-653271350_1024.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ...
#
# ...

# %%
path = '/content/drive/My Drive/Minor-Project/images/images/tomato vegetable/Image_1.jpg'
import cv2 
import matplotlib.pyplot as plt

i = cv2.imread(path)
i = cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
from bing_image_downloader import downloader
downloader.download("carrot vegetable", limit = 5 , output_dir = 'images' )

# %%
from bing_image_downloader import downloader
downloader.download("cucumber vegetable", limit = 5 , output_dir = 'images' )

# %%
import os
import cv2
path = '/content/drive/My Drive/Minor-Project/images/images/carrot vegetable'
for filename in os.listdir(path):
  i=cv2.imread(os.path.join(path,filename))
  print(i)
# Out:
# [[[  1  73  73]
#   [  0  72  72]
#   [  0  72  72]
#   ...
#   [ 76 100 118]
#   [ 76 100 118]
#   [ 76 100 118]]
#
#  [[  2  74  74]
#   [  2  74  74]
#   [  1  73  73]
#   ...
#   [ 76 100 118]
#   [ 76 100 118]
#   [ 76 100 118]]
#
#  [[  2  76  78]
#   [  2  76  78]
#   [  2  76  76]
#   ...
#   [ 76 100 118]
#   [ 76 100 118]
#   [ 76 100 118]]
#
#  ...
#
#  [[  6  57  53]
#   [  0  44  38]
#   [  0  30  23]
#   ...
#   [  6  26 138]
#   [  4  26 138]
#   [  5  27 139]]
#
#  [[ 19  70  66]
#   [  9  56  53]
#   [  3  43  38]
#   ...
#   [  4  24 136]
#   [  2  24 136]
#   [  3  25 137]]
#
#  [[ 30  83  80]
#   [ 20  70  66]
#   [ 15  55  50]
#   ...
#   [  3  23 135]
#   [  1  23 135]
#   [  2  24 136]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
# ...

# %%
import os 
from skimage.io import imread
from skimage.transform import resize

# %%
target = [] 
flat_data = []
images = []

import numpy as np

path = '/content/drive/My Drive/Minor-Project/images/images/'
for dirpath, dirnames, filenames in os.walk(path):
  for filename in filenames:
    category = dirpath.split('/')[-1]
    target.append(category)
    img = imread(f'{path}{category}/{filename}')
    img_resized = resize(img,(50,50,3))
    flat_data.append(img_resized.flatten())
    images.append(img_resized)

flat_data = np.array(flat_data)
images = np.array(images)
target = np.array(target)

print(flat_data.shape)
print(target.shape)
print(images.shape)
img
# Out:
# (15, 7500)
# (15,)
# (15, 50, 50, 3)
# array([[[49, 35, 24],
#         [54, 40, 29],
#         [58, 44, 33],
#         ...,
#         [ 2,  2,  2],
#         [ 2,  2,  2],
#         [ 2,  2,  2]],
#
#        [[51, 37, 28],
#         [54, 40, 31],
#         [57, 43, 34],
#         ...,
#         [ 2,  2,  2],
#         [ 2,  2,  2],
#         [ 2,  2,  2]],
#
#        [[52, 37, 30],
#         [54, 39, 32],
#         [55, 40, 33],
#         ...,
#         [ 2,  2,  2],
#         [ 2,  2,  2],
#         [ 2,  2,  2]],
#
#        ...,
#
#        [[36, 35, 43],
#         [36, 35, 43],
#         [36, 34, 45],
#         ...,
#         [ 7,  7,  7],
#         [ 7,  7,  7],
#         [ 7,  7,  7]],
#
#        [[38, 37, 45],
#         [38, 37, 45],
#         [38, 37, 45],
#         ...,
#         [ 6,  6,  6],
#         [ 7,  7,  7],
#         [ 7,  7,  7]],
#
#        [[39, 38, 46],
#         [38, 37, 45],
#         [38, 37, 45],
#         ...,
#         [ 6,  6,  6],
#         [ 7,  7,  7],
# ...

# %%
import pandas as pd 
df = pd.DataFrame(flat_data)
df['target']=target

# %%
df.tail()
# Out:
#            0         1         2  ...      7498      7499              target
# 10  0.492157  0.639216  0.201961  ...  0.968627  0.984314  cucumber vegetable
# 11  0.301961  0.356863  0.129412  ...  0.058824  0.011765  cucumber vegetable
# 12  0.980392  0.964706  0.952941  ...  0.850980  0.780392  cucumber vegetable
# 13  0.996078  0.996078  0.996078  ...  0.996078  0.996078  cucumber vegetable
# 14  0.258824  0.203922  0.160784  ...  0.027384  0.023529  cucumber vegetable
#
# [5 rows x 7501 columns]

# %%
df.shape
# Out:
# (15, 7501)

# %%
df.describe()
# Out:
#             0          1          2     ...       7497       7498       7499
# count  15.000000  15.000000  15.000000  ...  15.000000  15.000000  15.000000
# mean    0.725632   0.688417   0.584544  ...   0.707213   0.649995   0.594824
# std     0.330368   0.341490   0.437204  ...   0.354678   0.397412   0.439891
# min     0.138391   0.172549   0.049608  ...   0.027451   0.027384   0.011765
# 25%     0.422343   0.353627   0.145098  ...   0.535390   0.305980   0.121510
# 50%     0.943063   0.831373   0.854902  ...   0.862745   0.850980   0.780392
# 75%     0.998039   0.998039   0.998039  ...   0.998039   0.998039   0.998039
# max     1.000000   1.000000   1.000000  ...   1.000000   1.000000   1.000000
#
# [8 rows x 7500 columns]

# %%
x = df.iloc[:,0:7500].values
y = df.iloc[:,-1].values

# %%
y

# %%
from sklearn import preprocessing
from sklearn import utils

lab_enc = preprocessing.LabelEncoder()
y = lab_enc.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y, test_size=0.2,random_state=0)

# %%
x_train.shape

# %%
x_test.shape

# %%
y_test.shape

# %%
y_train.shape

# %%
y_test

# %%
print(utils.multiclass.type_of_target(y_train))

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3)
model.fit(x_train, y_train.astype('int'))
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
y_pred = model.predict(x_test)

# %%
y_pred

# %%
# checking the output
from skimage.io import imread
import matplotlib.pyplot as plt 
i = imread('https://upload.wikimedia.org/wikipedia/commons/thumb/8/89/Tomato_je.jpg/1200px-Tomato_je.jpg')
plt.imshow(i)

# %%
i.shape
# Out:
# (998, 1200, 3)

# %%
img_resized = resize(i,(50,50,3))
img_resized = img_resized.flatten()

# %%
model.predict([img_resized])

# %%
img_resized.shape

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(y_pred,y_test)
# Out:
# 0.6666666666666666

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[2, 1],
#        [0, 0]])
